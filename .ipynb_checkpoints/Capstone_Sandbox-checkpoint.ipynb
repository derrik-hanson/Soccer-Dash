# %%
# basics 
import pandas as pd
import numpy as np
import json

# visualization 
import plotly.express as px
import soccerplotly as socly

# soccer specific
from statsbombpy import sb

# %%
all_comps = sb.competitions()
# Out:
# credentials were not supplied. open data access only

# %%
all_comps[all_comps['match_available_360'] != 'None']
# Out:
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# 12              16         37                    Europe
# 13              16         44                    Europe
# 14              16         76                    Europe
# 15              37         90                   England
# ...

# %%
# Euro 2020 Compid
euro20_index = int(all_comps[all_comps['competition_name']=='UEFA Euro'].index.values)

# laliga 360 id
laliga360_mask = ((all_comps['competition_name']=='La Liga') &
                 (all_comps['season_name']=='2020/2021'))
laliga2021_index = int(all_comps[laliga360_mask].index.values)

print(f"Euro 20 index: {euro20_index}")
print(f" laliga index: {laliga2021_index}")
# Out:
# Euro 20 index: 38
#  laliga index: 19

# %%
all_comps.iloc[[laliga2021_index, euro20_index]]
# Out:
#     competition_id  season_id country_name competition_name  \
# 19              11         90        Spain          La Liga
# 38              55         43       Europe        UEFA Euro
#
#    competition_gender  competition_youth  competition_international  \
# 19               male              False                      False
# 38               male              False                       True
#
#    season_name               match_updated           match_updated_360  \
# 19   2020/2021     2022-02-11T14:56:09.076  2021-10-30T04:19:36.116600
# 38        2020  2022-02-01T17:20:34.319496  2021-11-11T13:54:37.507376
#
#            match_available_360             match_available
# 19  2021-09-17T15:18:33.787790     2022-02-11T14:56:09.076
# 38  2021-11-11T13:54:37.507376  2022-02-01T17:20:34.319496

# %%
euro20_matches = sb.matches(competition_id=55, season_id=43).sort_values(by='match_date', ascending=False)
display(euro20_matches)
# Out:
# credentials were not supplied. open data access only
#     match_id  match_date      kick_off         competition season  \
# 4    3795506  2021-07-11  21:00:00.000  Europe - UEFA Euro   2020
# 3    3795221  2021-07-07  21:00:00.000  Europe - UEFA Euro   2020
# 35   3795220  2021-07-06  21:00:00.000  Europe - UEFA Euro   2020
# 38   3795187  2021-07-03  21:00:00.000  Europe - UEFA Euro   2020
# 39   3795109  2021-07-03  18:00:00.000  Europe - UEFA Euro   2020
# 37   3795108  2021-07-02  18:00:00.000  Europe - UEFA Euro   2020
# 2    3795107  2021-07-02  21:00:00.000  Europe - UEFA Euro   2020
# 6    3794692  2021-06-29  21:00:00.000  Europe - UEFA Euro   2020
# 5    3794688  2021-06-29  18:00:00.000  Europe - UEFA Euro   2020
# 7    3794686  2021-06-28  18:00:00.000  Europe - UEFA Euro   2020
# 21   3794691  2021-06-28  21:00:00.000  Europe - UEFA Euro   2020
# 22   3794690  2021-06-27  18:00:00.000  Europe - UEFA Euro   2020
# ...

# %%
sb.events(match_id=3795506, split=True, flatten_attrs=False).keys()
# Out:
# credentials were not supplied. open data access only
# dict_keys(['starting_xis', 'half_starts', 'passes', 'ball_receipts', 'carrys', 'pressures', 'duels', 'blocks', 'interceptions', 'clearances', 'shots', 'goal_keepers', 'dribbles', 'foul_committeds', 'ball_recoverys', 'dispossesseds', 'foul_wons', 'miscontrols', 'dribbled_pasts', 'injury_stoppages', 'player_offs', 'player_ons', 'half_ends', 'substitutions', 'tactical_shifts', 'referee_ball_drops'])

# %%
player_name = "Marco Verratti"
df_passes = sb.events(match_id=3795506, split=True, flatten_attrs=False)["passes"] 

df_pass_m_ver = df_passes[df_passes['player']==player_name]
display(df_pass_m_ver.iloc[4])
display(df_pass_m_ver.iloc[4]['pass'])
event_id_test = df_pass_m_ver.iloc[4]['id']
# Out:
# credentials were not supplied. open data access only
# id                              7ee1f161-3fa5-493b-abee-943602c64e0a
# index                                                            157
# period                                                             1
# timestamp                                               00:05:23.394
# minute                                                             5
# second                                                            23
# type                                                            Pass
# possession                                                        10
# possession_team                                                Italy
# play_pattern                                          From Free Kick
# team                                                           Italy
# player                                                Marco Verratti
# position                                        Left Center Midfield
# ...

# %%
df_pass_m_ver.iloc[4]['location']
# Out:
# [48.3, 52.2]

# %%
def plot_pass_arrow(fig, event, pass_color='LightSeaGreen'):
    print("-- pass info --")
    start_loc = event['location']
    print(f"start: {start_loc}")
    end_loc = event['pass']['end_location']
    print(f"end: {end_loc}")
    height = event['pass']['height']
    print(f"height: {height}")

    fig.add_annotation(
        x=start_loc[0],  # arrows' head
        y=start_loc[1],  # arrows' head
        ax=end_loc[0],  # arrows' tail
        ay=end_loc[1],  # arrows' tail
        xref='x',
        yref='y',
        axref='x',
        ayref='y',
        text='',  # if you want only the arrow
        showarrow=True,
        arrowhead=3,
        arrowsize=1,
        arrowwidth=1,
        arrowcolor=pass_color
    )
    
    return fig

# %% [markdown]
# ---
# # 360 Data Exploration and Utility Development

# %%
### 360 utility functions

# %%
with open("/Users/Spade5/Downloads/three_sixty_data/3795506.json") as f:
    t6 = json.load(f)

# %%
all_frames = pd.DataFrame(t6)
all_frames
# Out:
#                                 event_uuid  \
# 0     0aee931f-9614-4879-b3e8-fd9d7cc80c59
# 1     307667b2-cc0e-4cf3-8528-ba4c86a1ba83
# 2     78b27402-d516-466f-9f33-20251b6079d1
# 3     9440989a-b1a0-4142-9907-1c9e69559ac7
# 4     a4d7d7f5-f0e1-4b9f-9f38-861f2d52608a
# ...                                    ...
# 4412  d58eac1c-2702-4f30-bb19-a1ee81373523
# 4413  a3629a8c-a31c-4393-8316-5b2abd4816db
# 4414  450ac72d-d9cd-4775-95db-076c899b9652
# 4415  e6fa5b12-3683-4e25-912b-30180e4fc752
# 4416  70c95651-ccf0-441f-814e-e9981997e335
#
#                                            visible_area  \
# 0     [95.1431344909299, 0.0, 73.027849532884, 80.0,...
# 1     [94.3718434181811, 0.0, 72.3230058929111, 79.0...
# 2     [94.3718434181811, 0.0, 72.3230058929111, 79.0...
# 3     [86.3609100357955, 0.0, 69.6365003796423, 80.0...
# 4     [67.9362988545138, 0.0, 63.4892860374376, 80.0...
# ...                                                 ...
# ...

# %%
all_frames.loc[2,'visible_area']
# Out:
# [94.3718434181811,
#  0.0,
#  72.3230058929111,
#  79.0931866042947,
#  48.3155386832784,
#  78.8600947483277,
#  26.9850461497717,
#  0.0,
#  94.3718434181811,
#  0.0]

# %%
fz_frame = all_frames['freeze_frame'].values[0]

frame = pd.DataFrame(fz_frame)

frame['x'] = frame.apply(lambda row: row.location[0], axis=1)
frame['y'] = frame.apply(lambda row: row.location[1], axis=1)
                        
frame
# Out:
#     teammate  actor  keeper                location          x          y
# 0       True  False   False   [32.666283, 23.82418]  32.666283  23.824180
# 1       True  False   False     [41.7286, 12.18034]  41.728600  12.180340
# 2       True  False   False   [48.86073, 40.878475]  48.860730  40.878475
# 3       True  False   False    [50.31848, 34.79487]  50.318480  34.794870
# 4       True  False   False    [53.75161, 51.89892]  53.751610  51.898920
# 5       True  False   False    [56.52155, 7.554894]  56.521550   7.554894
# 6      False  False   False  [59.558376, 27.612219]  59.558376  27.612219
# 7       True  False   False   [59.561153, 79.12628]  59.561153  79.126280
# 8       True   True   False   [59.93615, 40.167473]  59.936150  40.167473
# 9      False  False   False  [59.987797, 23.104885]  59.987797  23.104885
# 10     False  False   False   [60.18063, 51.683865]  60.180630  51.683865
# 11     False  False   False   [68.80735, 15.095798]  68.807350  15.095798
# ...

# %%
def plot_frame(frame):
    
    
    
    fig = px.scatter(frame, x="x", y="y", color='teammate', symbol='actor')
    fig = socly.draw_pitch_lines(fig)
    return fig

# %%
def get_local_360_file(mid):
    base_path = "/Users/Spade5/Downloads/three_sixty_data/"
    full_path = base_path + str(mid) + ".json"
    
    with open(full_path) as f:
        t6 = json.load(f)
    
    all_frames = pd.DataFrame(t6)
    return all_frames

# %%
def get_one_frame(full_frame, event_id):
    
    active_frame = full_df[full_df['event_uuid']==event_id]
    fz_frame = pd.DataFrame(active_frame['freeze_frame'].values)

    frame = pd.DataFrame(fz_frame)

    frame['x'] = frame.apply(lambda row: row['location'][0], axis=1)
    frame['y'] = frame.apply(lambda row: row['location'][1], axis=1)
    display(frame)
    return frame

# %%
full_df = get_local_360_file(3795506)

# %%
def plot_frame_2(frame):
    
    frame = pd.DataFrame(active_frame['freeze_frame'].values)
    
    frame['x'] = frame.apply(lambda row: row['location'][0], axis=1)
    frame['y'] = frame.apply(lambda row: row['location'][1], axis=1)
    display(frame)
    
    fig = px.scatter(frame, x="x", y="y", color='teammate', symbol='actor')
    fig = socly.draw_pitch_lines(fig)
    return fig

# %%
test_event = df_pass_m_ver.iloc[0]
event_id = test_event['id']

active_frame = full_df[full_df['event_uuid']==event_id]
display(active_frame)
fz_frame = pd.DataFrame(active_frame['freeze_frame'].values)

frame = pd.DataFrame(fz_frame)

# frame['x'] = frame.apply(lambda row: row['location'][0], axis=1)
# frame['y'] = frame.apply(lambda row: row['location'][1], axis=1)
# display(frame)
# Out:
#                              event_uuid  \
# 3  9440989a-b1a0-4142-9907-1c9e69559ac7
#
#                                         visible_area  \
# 3  [86.3609100357955, 0.0, 69.6365003796423, 80.0...
#
#                                         freeze_frame
# 3  [{'teammate': True, 'actor': False, 'keeper': ...

# %%
print(test_event['location'])
test_event['id']
frame_0 = get_one_frame(full_df, event_id=test_event['id'])
frame_0
# Out:
# [48.0, 35.7]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-234-92813c2cb766> in <module>
#       1 print(test_event['location'])
#       2 test_event['id']
# ----> 3 frame_0 = get_one_frame(full_df, event_id=test_event['id'])
#       4 frame_0
#
# <ipython-input-214-f426f964ca5c> in get_one_frame(full_frame, event_id)
#       6     frame = pd.DataFrame(fz_frame)
#       7
# ----> 8     frame['x'] = frame.apply(lambda row: row['location'][0], axis=1)
#       9     frame['y'] = frame.apply(lambda row: row['location'][1], axis=1)
#      10     display(frame)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
# ...

# %%
test_event = df_pass_m_ver.iloc[0]
test_event['id']
frame_0 = get_one_frame(full_df, event_id=test_event['id'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-235-2d22a9882a15> in <module>
#       1 test_event = df_pass_m_ver.iloc[0]
#       2 test_event['id']
# ----> 3 frame_0 = get_one_frame(full_df, event_id=test_event['id'])
#
# <ipython-input-214-f426f964ca5c> in get_one_frame(full_frame, event_id)
#       6     frame = pd.DataFrame(fz_frame)
#       7
# ----> 8     frame['x'] = frame.apply(lambda row: row['location'][0], axis=1)
#       9     frame['y'] = frame.apply(lambda row: row['location'][1], axis=1)
#      10     display(frame)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# ...

# %%
test_event = df_pass_m_ver.iloc[3]
frame_0 = get_one_frame(full_df, event_id=test_event['id'])

fig = plot_frame(frame_0)
fig = plot_pass_arrow(fig, test_event, pass_color='LightSeaGreen')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'y'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ## useless reference

# %%
# Sample 360 Frame

match_frames = sb.frames(match_id=3795506, fmt='dataframe')
# Out:
# credentials were not supplied. open data access only
# /Users/Spade5/opt/anaconda3/lib/python3.8/site-packages/statsbombpy/public.py:39: UserWarning:
#
# There is currently no open 360 data, returning empty dict
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-ee74d62251d1> in <module>
#       1 # Sample 360 Frame
#       2
# ----> 3 match_frames = sb.frames(match_id=3795506, fmt='dataframe')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsbombpy/sb.py in frames(match_id, fmt, creds)
#     134         frames = public.frames(match_id)
#     135     if fmt == "dataframe":
# --> 136         frames = pd.json_normalize(
#     137             frames, "freeze_frame", ["event_uuid", "visible_area"]
#     138         )
#
# ...

# %%
comp_frames = sb.competition_frames(
    country="Germany",
    division= "1. Bundesliga",
    season="2019/2020"
)
match_frames
